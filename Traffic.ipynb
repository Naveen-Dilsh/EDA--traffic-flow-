# %% [markdown]
# <a href="https://colab.research.google.com/github/Naveen-Dilsh/EDA--traffic-flow-/blob/main/Traffic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Traffic flow england scotland wales accidents Exploratory Data Analysis**

# %%
pip install opendatasets --upgrade --quiet

# %% [markdown]
# ## Download the Data

# %%
import opendatasets as od

download_url = 'https://www.kaggle.com/datasets/daveianhickey/2000-16-traffic-flow-england-scotland-wales'

od.download(download_url)
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: naveendilsh
# Your Kaggle Key: ··········
# Dataset URL: https://www.kaggle.com/datasets/daveianhickey/2000-16-traffic-flow-england-scotland-wales
# ...
# 100%|██████████| 132M/132M [00:00<00:00, 865MB/s]

# %%
# {"username":"naveendilsh","key":"f2c66b5040c7c6ba7698137a856cbad3"}

# %%
data_filename = "./2000-16-traffic-flow-england-scotland-wales/accidents_2012_to_2014.csv"

# %% [markdown]
# ## Data Preparation and Cleaning
#
# 1. Load the file using Pandas
# 2. Look at some information about the data & the columns
# 3. Fix any missing or incorrect values

# %%
import pandas as pd

# %%
df = pd.read_csv(data_filename)
# Out:
# /tmp/ipython-input-560053455.py:1: DtypeWarning: Columns (31) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(data_filename)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#        Accident_Index  Location_Easting_OSGR  Location_Northing_OSGR  \
# 0       201201BS70001                 527200                  178760
# 1       201201BS70002                 524930                  181430
# 2       201201BS70003                 525860                  178080
# 3       201201BS70004                 524980                  181030
# 4       201201BS70005                 526170                  179200
# ...               ...                    ...                     ...
# 464692       2.01E+12                 310037                  597647
# 464693       2.01E+12                 321509                  574063
# 464694       2.01E+12                 321337                  566365
# 464695       2.01E+12                 323869                  566853
# 464696       2.01E+12                 314072                  579971
#
#         Longitude   Latitude  Police_Force  Accident_Severity  \
# 0       -0.169101  51.493429             1                  3
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 464697 entries, 0 to 464696
# Data columns (total 33 columns):
#  #   Column                                       Non-Null Count   Dtype
# ---  ------                                       --------------   -----
#  0   Accident_Index                               464697 non-null  object
#  1   Location_Easting_OSGR                        464697 non-null  int64
#  2   Location_Northing_OSGR                       464697 non-null  int64
#  3   Longitude                                    464697 non-null  float64
#  4   Latitude                                     464697 non-null  float64
#  5   Police_Force                                 464697 non-null  int64
#  6   Accident_Severity                            464697 non-null  int64
#  7   Number_of_Vehicles                           464697 non-null  int64
#  8   Number_of_Casualties                         464697 non-null  int64
# ...

# %%
df.describe()
# Out:
#        Location_Easting_OSGR  Location_Northing_OSGR      Longitude  \
# count          464697.000000            4.646970e+05  464697.000000
# mean           443834.284222            2.986258e+05      -1.375156
# std             94098.865933            1.594701e+05       1.382137
# min             65510.000000            1.029000e+04      -7.509162
# 25%            379059.000000            1.777100e+05      -2.315799
# 50%            445539.000000            2.606800e+05      -1.323374
# 75%            525350.000000            3.989590e+05      -0.192935
# max            655370.000000            1.190858e+06       1.759382
#
#             Latitude   Police_Force  Accident_Severity  Number_of_Vehicles  \
# count  464697.000000  464697.000000      464697.000000       464697.000000
# mean       52.575498      28.504051           2.833461            1.828086
# std         1.436370      25.334899           0.402029            0.708703
# ...

# %%
# how numeric data in here
numerics =['int16','int32','int64','float16','float32','float64']
numeric_df= df.select_dtypes(include = numerics)
len(numeric_df.columns)
# Out:
# 18

# %%
# missing value columns sums
# df.isna().sum()
# df.isna().sum().sort_values(ascending=False)
missing_percentages = df.isna().sum().sort_values(ascending=False)/len(df)
missing_percentages
# Out:
# Junction_Detail                                1.000000
# Carriageway_Hazards                            0.983114
# Special_Conditions_at_Site                     0.977813
# Junction_Control                               0.384358
# LSOA_of_Accident_Location                      0.061799
# Road_Surface_Conditions                        0.001625
# Time                                           0.000028
# Did_Police_Officer_Attend_Scene_of_Accident    0.000004
# Accident_Index                                 0.000000
# Number_of_Casualties                           0.000000
# Location_Easting_OSGR                          0.000000
# Longitude                                      0.000000
# Location_Northing_OSGR                         0.000000
# Police_Force                                   0.000000
# Accident_Severity                              0.000000
# Number_of_Vehicles                             0.000000
# Latitude                                       0.000000
# ...

# %%
#with zeros also
# missing_percentages.plot(kind='barh')

#missing_percentages !=0 if percentage == 0 so all completed. != mean no values
#with out Zeros
missing_percentages[missing_percentages != 0].plot(kind="barh")
# Out:
# <Axes: >

# %% [markdown]
# Remove columns that you don't want to use . if some columns missing the half of the time(like junction_detail,carr..,spe..)

# %% [markdown]
# ## Exploratory Analysis and Visualization
#
# ### columns we analyze :
# 1. Police_Force
# 2. Day_of_Week
# 3. Speed_limit
# 4. Light_Conditions
# 5. Weather_Conditions

# %%
df.columns
# Out:
# Index(['Accident_Index', 'Location_Easting_OSGR', 'Location_Northing_OSGR',
#        'Longitude', 'Latitude', 'Police_Force', 'Accident_Severity',
#        'Number_of_Vehicles', 'Number_of_Casualties', 'Date', 'Day_of_Week',
#        'Time', 'Local_Authority_(District)', 'Local_Authority_(Highway)',
#        '1st_Road_Class', '1st_Road_Number', 'Road_Type', 'Speed_limit',
#        'Junction_Detail', 'Junction_Control', '2nd_Road_Class',
#        '2nd_Road_Number', 'Pedestrian_Crossing-Human_Control',
#        'Pedestrian_Crossing-Physical_Facilities', 'Light_Conditions',
#        'Weather_Conditions', 'Road_Surface_Conditions',
#        'Special_Conditions_at_Site', 'Carriageway_Hazards',
#        'Urban_or_Rural_Area', 'Did_Police_Officer_Attend_Scene_of_Accident',
#        'LSOA_of_Accident_Location', 'Year'],
#       dtype='object')

# %%
# the specific police force area that recorded or investigated the traffic incident/accident
df.Police_Force
# Out:
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
#           ..
# 464692    98
# 464693    98
# 464694    98
# 464695    98
# 464696    98
# Name: Police_Force, Length: 464697, dtype: int64

# %%
police_Force = df.Police_Force.unique()
len(police_Force)
# Out:
# 51

# %%
# how many traffic incidents were recorded by each police force
police_Force_by_investigated = df.Police_Force.value_counts()
police_Force_by_investigated
# Out:
# Police_Force
# 1     82701
# 13    16951
# 6     16621
# 43    16037
# 20    15556
# 4     15512
# 46    14929
# 44    13743
# 10    12698
# 47    12153
# 42    11908
# 50    11904
# 45    11722
# 5     11586
# 97    11040
# 7     10882
# 52     9962
# 14     9315
# 21     8461
# 31     8376
# 12     8261
# 16     7854
# 41     7596
# 33     7335
# 30     7211
# 22     7151
# 62     6956
# 32     6796
# 95     6452
# 35     6435
# 55     5461
# 36     5428
# 37     5247
# 3      5113
# 11     4918
# 23     4620
# 54     4496
# 60     4395
# 40     4357
# 63     3892
# 34     3705
# 17     2829
# 92     2747
# 53     2651
# 61     2499
# 93     1892
# 96     1580
# 91     1552
# 94     1253
# 48     1033
# 98      925
# Name: count, dtype: int64

# %%
df['Police_Force'].isin([1]).any()
# Out:
# np.True_

# %%
police_Force_by_investigated[:20].plot(kind="barh")
# Out:
# <Axes: ylabel='Police_Force'>

# %%
import seaborn as sns
sns.set_style("darkgrid")

# %%
sns.distplot(police_Force_by_investigated)
# Out:
# /tmp/ipython-input-1073242834.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(police_Force_by_investigated)
# <Axes: xlabel='count', ylabel='Density'>

# %% [markdown]
# ## Ask & answer Questions
#
# 1. How is the weather conditions more accidents happend ?
# 2. what day of week more accidents are happend ?
# 3. what time more accidents happend ?

# %% [markdown]
# ## Summary and Conclusion
